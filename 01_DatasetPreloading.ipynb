# %% [markdown]
# # Importing Required Libraries

# %%
# Libraries for Data Manipulation
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading and Inspecting Dataset

# %%
NB15_1 = pd.read_csv('./Dataset/UNSW-NB15_1.csv', low_memory=False)
NB15_2 = pd.read_csv('./Dataset/UNSW-NB15_2.csv', low_memory=False)
NB15_3 = pd.read_csv('./Dataset/UNSW-NB15_3.csv', low_memory=False)
NB15_4 = pd.read_csv('./Dataset/UNSW-NB15_4.csv', low_memory=False)



LIST_EVENTS = pd.read_csv('./Dataset/UNSW-NB15_LIST_EVENTS.csv')


NB15_features = pd.read_csv('.//Dataset/NUSW-NB15_features.csv', encoding='cp1252')


training_set = pd.read_csv('./Dataset/Training and Testing Sets/UNSW_NB15_training-set.csv')
testing_set = pd.read_csv('./Dataset/Training and Testing Sets/UNSW_NB15_testing-set.csv')

# %% [markdown]
# # Inspecting the data

# %%
NB15_1.head()
# Out:
#    59.166.0.0   1390  149.171.126.6    53  udp  CON  0.001055  132  164  31  \
# 0  59.166.0.0  33661  149.171.126.9  1024  udp  CON  0.036133  528  304  31
# 1  59.166.0.6   1464  149.171.126.7    53  udp  CON  0.001119  146  178  31
# 2  59.166.0.5   3593  149.171.126.5    53  udp  CON  0.001209  132  164  31
# 3  59.166.0.3  49664  149.171.126.0    53  udp  CON  0.001169  146  178  31
# 4  59.166.0.0  32119  149.171.126.9   111  udp  CON  0.078339  568  312  31
#
#    ...  0.17   3  7  1  3.1  1.1  1.2  1.3  Unnamed: 47  0.18
# 0  ...     0   2  4  2    3    1    1    2          NaN     0
# 1  ...     0  12  8  1    2    2    1    1          NaN     0
# 2  ...     0   6  9  1    1    1    1    1          NaN     0
# 3  ...     0   7  9  1    1    1    1    1          NaN     0
# 4  ...     0   2  4  2    3    1    1    2          NaN     0
#
# [5 rows x 49 columns]

# %%
NB15_1.shape
# Out:
# (700000, 49)

# %%
NB15_2.head()
# Out:
#    59.166.0.0   6055  149.171.126.5  54145  tcp  FIN  0.072974  4238  60788  \
# 0  59.166.0.0   7832  149.171.126.3   5607  tcp  FIN  0.144951  5174  91072
# 1  59.166.0.8  11397  149.171.126.6     21  tcp  FIN  0.116107  2934   3742
# 2  59.166.0.0   3804  149.171.126.3     53  udp  CON  0.000986   146    178
# 3  59.166.0.8  14339  149.171.126.6  14724  tcp  FIN  0.038480  8928    320
# 4  59.166.0.8  39094  149.171.126.3     53  udp  CON  0.001026   130    162
#
#    31  ...  0.6  13  13.1  6  7.1  1  1.1  2  Unnamed: 47  0.7
# 0  31  ...    0  13    13  6    7  1    1  2          NaN    0
# 1  31  ...    1   1     2  7    5  1    1  4          NaN    0
# 2  31  ...    0  13    13  6    7  1    1  2          NaN    0
# 3  31  ...    0   8    20  7    5  1    1  4          NaN    0
# 4  31  ...    0   8    13  6    5  1    1  1          NaN    0
#
# [5 rows x 49 columns]

# %%
NB15_2.shape
# Out:
# (700000, 49)

# %%
NB15_3.head()
# Out:
#        59.166.0.1  18247  149.171.126.4   7662  tcp  FIN  0.119596   4550  \
# 0      59.166.0.3  54771  149.171.126.2  27709  tcp  FIN  0.650574   8928
# 1      59.166.0.8  13289  149.171.126.9   5190  tcp  FIN  0.007980   2158
# 2  149.171.126.18   1043   175.45.176.3     53  udp  INT  0.000005    264
# 3  149.171.126.18   1043   175.45.176.3     53  udp  INT  0.000005    264
# 4      59.166.0.3  10275  149.171.126.0     25  tcp  FIN  0.486578  37462
#
#    68342  31  ...      6   2 2.1   5   1  1.1  2.2  Unnamed: 47  0.4
# 0    320  31  ...      3   5   2   4   1    1    4          NaN    0
# 1   2464  31  ...      3   5   1   1   1    1    3          NaN    0
# 2      0  60  ...     19  19  19  19  19   19   19          NaN    0
# 3      0  60  ...     19  19  19  19  19   19   19          NaN    0
# 4   3380  31  ...      3   2   3   4   2    1    2          NaN    0
#
# [5 rows x 49 columns]

# %%
NB15_3.shape
# Out:
# (700000, 49)

# %%
NB15_4.head()
# Out:
#    59.166.0.9   7045  149.171.126.7    25  tcp  FIN  0.201886  37552     3380  \
# 0  59.166.0.9   9685  149.171.126.2    80  tcp  FIN  5.864748  19410  1087890
# 1  59.166.0.2   1421  149.171.126.4    53  udp  CON  0.001391    146      178
# 2  59.166.0.2  21553  149.171.126.2    25  tcp  FIN  0.053948  37812     3380
# 3  59.166.0.8  45212  149.171.126.4    53  udp  CON  0.000953    146      178
# 4  59.166.0.0  59922  149.171.126.8  6881  tcp  FIN  8.633186  25056  1094788
#
#    31  ...     2  2.1  7  4  1  1.1  3  Unnamed: 47  0.4
# 0  31  ...     3    1  4  4  1    1  1          NaN    0
# 1  31  ...     3    5  2  7  1    1  4          NaN    0
# 2  31  ...     1    1  4  7  1    1  3          NaN    0
# 3  31  ...     2    5  2  1  1    1  2          NaN    0
# 4  31  ...     9    7  2  3  2    1  6          NaN    0
#
# [5 rows x 49 columns]

# %%
NB15_4.shape
# Out:
# (440043, 49)

# %% [markdown]
# # List Of Events

# %%
LIST_EVENTS
# Out:
#     Attack category Attack subcategory  Number of events
# 0            normal                NaN           2218761
# 1          Fuzzers                 FTP               558
# 2          Fuzzers                HTTP              1497
# 3          Fuzzers                 RIP              3550
# 4          Fuzzers                 SMB              5245
# ..              ...                ...               ...
# 203       Shellcode           Decoders                18
# 204       Shellcode        Multiple OS                10
# 205       Shellcode            Solaris                12
# 206           Worms                                  174
# 207             NaN             Total            2540044
#
# [208 rows x 3 columns]

# %% [markdown]
# # Understanding About The Features

# %%
NB15_features
# Out:
#     No.   Name               Type        \
# 0      1  srcip              nominal
# 1      2  sport              integer
# 2      3  dstip              nominal
# 3      4  dsport             integer
# 4      5  proto              nominal
# 5      6  state              nominal
# 6      7  dur                Float
# 7      8  sbytes             Integer
# 8      9  dbytes             Integer
# 9     10  sttl               Integer
# 10    11  dttl               Integer
# 11    12  sloss              Integer
# 12    13  dloss              Integer
# 13    14  service            nominal
# 14    15  Sload              Float
# 15    16  Dload              Float
# 16    17  Spkts              integer
# 17    18  Dpkts              integer
# 18    19  swin               integer
# 19    20  dwin               integer
# 20    21  stcpb              integer
# 21    22  dtcpb              integer
# 22    23  smeansz            integer
# 23    24  dmeansz            integer
# ...

# %% [markdown]
# # Concatenating The DataFiles

# %%
NB15_features.columns = NB15_features.columns.str.strip()

print(NB15_features.columns)
# Out:
# Index(['No.', 'Name', 'Type', 'Description'], dtype='object')

# %%
NB15_1.columns = NB15_features['Name'] 
NB15_2.columns = NB15_features['Name'] 
NB15_3.columns = NB15_features['Name'] 
NB15_4.columns = NB15_features['Name']

# %% [markdown]
# # Creating The Training Dataset

# %%
fullDF = pd.concat([NB15_1, NB15_2, NB15_3, NB15_4], ignore_index=True)

# %%
# Shuffle the data points in train_df
fullDF = fullDF.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
fullDF
# Out:
# Name    srcip             sport             dstip              \
# 0            175.45.176.3             57672    149.171.126.15
# 1              59.166.0.8             38052     149.171.126.9
# 2              59.166.0.0             42911     149.171.126.2
# 3            175.45.176.1             47439    149.171.126.14
# 4              59.166.0.5             61544     149.171.126.6
# ...                   ...               ...               ...
# 2540038        59.166.0.8             34415     149.171.126.0
# 2540039        59.166.0.8             56352     149.171.126.2
# 2540040        59.166.0.9             25527     149.171.126.4
# 2540041      175.45.176.1             47439    149.171.126.14
# 2540042    149.171.126.14              1043      175.45.176.1
#
# Name    dsport            proto             state              \
# 0                    3260               tcp               CON
# 1                    6881               tcp               FIN
# ...
